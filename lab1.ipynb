# %% [markdown]
# <a href="https://colab.research.google.com/github/renikindiamulya/aiml-lab-2024-25_batch11/blob/main/lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import  numpy as np
lst1=[1,2,3]
array1=np.array(lst1)
print("list = ",lst1)
print("array = ",array1)
# Out:
# list =  [1, 2, 3]
# array =  [1 2 3]

# %%
 import  numpy as np
 lst1=[1,2,3]
 array1=np.array(lst1)
 print("list = ",lst1)
 print("array = ",array1)
# Out:
# list =  [1, 2, 3]
# array =  [1 2 3]

# %%
  import numpy as np
  lst1=[1,2,3]
  array1=np.array(lst1)
  print("list = ",lst1)
  print("array = ",array1)
  type(lst1)
  type(array1)
  print(array1.ndim)
# Out:
# list =  [1, 2, 3]
# array =  [1 2 3]
# 1

# %%
 import numpy as np
 array1=np.array([10,20,30])
 array2=np.array([2,2,2])
 print("array multiplied by array1:",array1*array2)
 print("array division  by array1:",array2/array1)
 print("array raised to the power of array1:",array2^array1)
# Out:
# array multiplied by array1: [20 40 60]
# array division  by array1: [0.2        0.1        0.06666667]
# array raised to the power of array1: [ 8 22 28]

# %%
import numpy as np
array1 = np.array([10,20,30])
array2 = np.array([2,2,2])
addition = array1 + array2
text1 = "sr"
text2 = "sumathi reddy"
combined_text = text1 + " " + text2
print("Addition of Two: ", addition)
print(combined_text)
# Out:
# Addition of Two:  [12 22 32]
# sr sumathi reddy

# %%
import numpy as np
array1=np.array([10,20,30])

print("sine:.",np.log(array1))

print("natural logarithm: ",np.log(array1))
print("base-10 logarithm: ",np.log10(array1))
print("base-2 logarithm: ",np.log2(array1))

print("exponential: ",np.exp(array1))
# Out:
# sine:. [2.30258509 2.99573227 3.40119738]
# natural logarithm:  [2.30258509 2.99573227 3.40119738]
# base-10 logarithm:  [1.         1.30103    1.47712125]
# base-2 logarithm:  [3.32192809 4.32192809 4.9068906 ]
# exponential:  [2.20264658e+04 4.85165195e+08 1.06864746e+13]

# %%
import matplotlib.pyplot as plt

people = ['sai', 'gopi', 'ghouse', 'rahul']
age = [25, 30, 35, 40]
height = [145, 151, 165, 173]
weight = [45, 55, 65, 75]

# %%
 plt.figure(figsize=(8, 6))
 plt.scatter(age, height, c='blue', label='Height')
 plt.scatter(age, weight, c='red', label='Weight')
 plt.title('Scatter Plot of Age vs. Height and Weight')
 plt.xlabel('Age')
 plt.ylabel('Height and Weight')
 plt.legend()
 plt.grid(True)
 plt.show()

# %%
plt.figure(figsize=(8, 6))
bar_width = 0.35
index = range(len(people))
plt.bar(index, height, width=bar_width, label='Height', color='blue')
plt.bar([i + bar_width for i in index], weight, width=bar_width, label='Weight', color='red')
plt.xlabel('People')
plt.ylabel('Height and Weight')
plt.title('Bar Chart of Height and Weight for Each Person')
plt.xticks([i + bar_width/2 for i in index], people)
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.hist(height, bins=10, alpha=0.7, color='blue', label='Height')
plt.hist(weight, bins=10, alpha=0.7, color='red', label='Weight')
plt.title('Histogram of Height and Weight')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.legend()
plt.grid(True)
plt.show()

# %%
import pandas as pd
data_excel = pd.read_excel('"D:\age.xlsx"')
data_csv= pd.read_csv('"D:\age.csv"')
data_tsv= pd.read_csv('"D:\age.txt"', sep='\t')
print(data_excel)
print(data_csv)
print(data_tsv)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-18-ecbd6eedc8de> in <cell line: 2>()
#       1 import pandas as pd
# ----> 2 data_excel = pd.read_excel('"D:\age.xlsx"')
#       3 data_csv= pd.read_csv('"D:\age.csv"')
#       4 data_tsv= pd.read_csv('"D:\age.txt"', sep='\t')
#       5 print(data_excel)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, decimal, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     480     if not isinstance(io, ExcelFile):
#     481         should_close = True
# --> 482         io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     483     elif engine and engine != io.engine:
#     484         raise ValueError(
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/excel/_base.py in __init__(self, path_or_buffer, engine, storage_options)
#    1650                 ext = "xls"
#    1651             else:
# -> 1652                 ext = inspect_excel_format(
#    1653                     content_or_path=path_or_buffer, storage_options=storage_options
#    1654                 )
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/excel/_base.py in inspect_excel_format(content_or_path, storage_options)
#    1523         content_or_path = BytesIO(content_or_path)
#    1524
# -> 1525     with get_handle(
#    1526         content_or_path, "rb", storage_options=storage_options, is_text=False
#    1527     ) as handle:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     863         else:
#     864             # Binary mode
# --> 865             handle = open(handle, ioargs.mode)
#     866         handles.append(handle)
#     867
#
# FileNotFoundError: [Errno 2] No such file or directory: '"D:\x07ge.xlsx"'
